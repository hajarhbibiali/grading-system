# %%
# !pip3 install nltk
# !pip3 install -U nltk
# !pip3 install gensim
# Out:
# Requirement already satisfied: nltk in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\chaimae\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: nltk in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\chaimae\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: gensim in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from gensim) (1.26.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from gensim) (6.4.0)

# %%
import pandas as pd
import os
import numpy as np
import re
import tensorflow as tf
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tag.perceptron import PerceptronTagger
from nltk.stem import SnowballStemmer
from gensim.models import Word2Vec
# Out:
# WARNING:tensorflow:From c:\Users\chaimae\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
nltk.download('wordnet')

nltk.download('stopwords')
# stop words
arb_stopwords = set(nltk.corpus.stopwords.words("arabic"))

from nltk.stem.arlstem import ARLSTem
stemmer = ARLSTem()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\chaimae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chaimae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
questions = pd.read_csv("../datasets/questions.csv", encoding='utf-8')
answers = pd.read_csv("../datasets/answers.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 questions = pd.read_csv("../datasets/questions.csv", encoding='utf-8')
#       2 answers = pd.read_csv("../datasets/answers.csv", encoding='utf-8')
#       3 answers.head
#
# NameError: name 'pd' is not defined

# %%
# Supprimer les lignes avec des valeurs manquantes
answers['answer'].isnull().sum()
questions.dropna(inplace=True)
answers.dropna(inplace=True)

# %%
# Convertir 'score' en int64 
answers['grade'] = answers['grade'].astype(int)
# Conversion 'question' et 'answer' en type 'str' 
questions['question'] = questions['question'].astype(str)
answers['answer'] = answers['answer'].astype(str)
questions
# Out:
#     id_question                                     question
# 0           1.0             من هو خاتم الأنبياء والمرسلين؟
# 1           2.0                     كم استمرت الدعوة السرية؟
# 2           3.0               ما هي السور التي بدأت بالحمد ؟
# 3           4.0    ما هو اسم والدة نبي الله عيسى عليه السلام
# 4           5.0       من هي أول من دخل في الإسلام من النساء؟
# 5           6.0         ما هي السورة التي لا تبتدأ بالبسملة؟
# 6           7.0  ما هو اسم مرضعة الرسول صلى الله عليه وسلم ؟
# 7           8.0               من هو النبي الذي التقمه الحوت؟
# 8           9.0    ما هي السورة التي تحدثت عن تقسيم الغنائم؟
# 9          10.0           ما هي أقصر سورة في القرآن الكريم ؟
# 34          1.0             من هو خاتم الأنبياء والمرسلين؟
# 35          2.0                     كم استمرت الدعوة السرية؟
# 36          3.0               ما هي السور التي بدأت بالحمد ؟
# 37          4.0    ما هو اسم والدة نبي الله عيسى عليه السلام
# 38          5.0       من هي أول من دخل في الإسلام من النساء؟
# 39          6.0        ما هي السورة التي لا تبتدأ  بالبسملة؟
# 40          7.0  ما هو اسم مرضعة الرسول صلى الله عليه وسلم ؟
# 41          8.0               من هو النبي الذي التقمه الحوت؟
# 42          9.0    ما هي السورة التي تحدثت عن تقسيم الغنائم؟
# 43         10.0           ما هي أقصر سورة في القرآن الكريم ؟

# %%
# Suppression des doublons :
questions.drop_duplicates(inplace=True)
answers.drop_duplicates(inplace=True)
#définir 'id_question' comme index
answers.set_index('question_id', inplace=True)

# %%
# Distribution des scores
sns.countplot(x='grade', data=answers)
plt.title('Distribution des Scores')
plt.show()

# %%
# Function to clean text
def clean_text(text):
    # Define the characters you want to remove
    characters_to_remove = ["''", ':', '؟']

    # Remove specified characters
    for char in characters_to_remove:
        text = text.replace(char, '')

    # Remove `` and ''
    text = text.replace('``', '').replace("''", '')

    return text

# Apply the clean_text function to the 'question' column in the 'questions' DataFrame

# Apply the clean_text function to the 'answer' column in the 'answers' DataFrame
answers['answer'] = answers['answer'].apply(clean_text)

# %%
answers

# %%
ans = answers['answer']
scores = answers['grade']
scores = tf.keras.utils.to_categorical(
    scores, num_classes=3, dtype='float32'
)

# %%
# Function to clean and preprocess text
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text.strip())

    # Removal of stop words
    tokens = [word for word in tokens if word not in arb_stopwords]

    # Stemming
    tokens = [stemmer.stem(word) for word in tokens]

    # Lemmatization
    lemmatized_tokens = [WordNetLemmatizer().lemmatize(word) for word in tokens]

    # Concatenate tokens into a single string
    preprocessed_text = ' '.join(lemmatized_tokens)

    return preprocessed_text, lemmatized_tokens

# Apply the preprocessing function to the 'question' column
answers['answer'], answers['answer'] = zip(*answers['answer'].apply(preprocess_text))

# %%
answers
# Out:
#                             answer  grade
# question_id
# 1            [محمد, صلي, الل, سلم]      2
# 1                     [خاتم, نبيء]      2
# 1                     [رسول, اعظم]      2
# 1                      [سيد, مرسل]      2
# 1               [صاحب, رسال, خاتم]      2
# ...                            ...    ...
# 10                           [كهف]      0
# 10                           [فرق]      0
# 10                       [ال, عمر]      0
# 10                           [سرء]      0
# 10                          [مريم]      0
#
# [870 rows x 2 columns]

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from gensim) (1.26.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\chaimae\appdata\local\programs\python\python310\lib\site-packages (from gensim) (6.4.0)

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ar.vec -P ./
# Out:
# 'wget' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
from gensim.models import KeyedVectors
absolute_path = "./wiki.ar.vec"  # Replace with the actual absolute path
fasttext_model = KeyedVectors.load_word2vec_format(absolute_path)

# %%
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

#train tokenization
tokenizer = Tokenizer(filters=''''!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''''' )
combined_texts = answers['answer']
tokenizer.fit_on_texts(combined_texts)
sequences = tokenizer.texts_to_sequences(combined_texts)
max_sequence_length = max(len(s) for s in sequences)
sequences = pad_sequences(sequences, max_sequence_length)
word2idx = tokenizer.word_index
vocab_size = len(word2idx) + 1

# %%
# Word Embedding
from keras.layers import Embedding
import numpy as np

EMBEDDING_DIM = 300
num_words = len(word2idx) + 1

# Prepare embedding matrix
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
count = 0  # Initialize count here
for word, idx in word2idx.items():
    if word in fasttext_model:
        embedding_matrix[idx] = fasttext_model.get_vector(word)
    else:
        count += 1
        print("Word not exist in vocab: " + word)
# Out:
# Word not exist in vocab: انعام،
# Word not exist in vocab: 3
# Word not exist in vocab: ''
# Word not exist in vocab: ``
# Word not exist in vocab: ارضع
# Word not exist in vocab: مرضع
# Word not exist in vocab: بتلع
# Word not exist in vocab: فتتح
# Word not exist in vocab: نبيء
# Word not exist in vocab: اسلام،
# Word not exist in vocab: ربم
# Word not exist in vocab: حتوي
# Word not exist in vocab: خري
# Word not exist in vocab: اريخ
# Word not exist in vocab: قران،
# Word not exist in vocab: يتامي
# Word not exist in vocab: شريع
# Word not exist in vocab: عقوب
# Word not exist in vocab: 5
# Word not exist in vocab: فاطرهي
# Word not exist in vocab: بالل
# Word not exist in vocab: وزيع
# Word not exist in vocab: 10
# Word not exist in vocab: عالمين،
# Word not exist in vocab: بتدئ
# Word not exist in vocab: مائد
# Word not exist in vocab: بعيسي
# Word not exist in vocab: ختر
# Word not exist in vocab: هب،
# Word not exist in vocab: بدعو
# Word not exist in vocab: بخديج
# Word not exist in vocab: تبتد
# Word not exist in vocab: بيئ
# Word not exist in vocab: رعاي
# Word not exist in vocab: انفال،
# Word not exist in vocab: نتصر
# Word not exist in vocab: غنائ
# Word not exist in vocab: ايت،
# Word not exist in vocab: انبياء،
# Word not exist in vocab: رعرع
# Word not exist in vocab: جهري
# Word not exist in vocab: مكرمة،
# Word not exist in vocab: فاتحة،الانعام،
# Word not exist in vocab: حيء
# Word not exist in vocab: دته
# Word not exist in vocab: اسمين،
# Word not exist in vocab: رة،
# Word not exist in vocab: لخديج
# Word not exist in vocab: اريخي
# Word not exist in vocab: سمء
# Word not exist in vocab: ستثنء
# Word not exist in vocab: لبسمل
# Word not exist in vocab: اهمي
# Word not exist in vocab: اسسا
# Word not exist in vocab: خزاع
# Word not exist in vocab: طفول
# Word not exist in vocab: اموم
# Word not exist in vocab: صيب
# Word not exist in vocab: بينم
# Word not exist in vocab: ارء
# Word not exist in vocab: لفتر
# Word not exist in vocab: 3-5
# Word not exist in vocab: 13
# Word not exist in vocab: نتهء
# Word not exist in vocab: ستمرر
# Word not exist in vocab: لـ3
# Word not exist in vocab: رفاهي
# Word not exist in vocab: منورة،
# Word not exist in vocab: ضطهد
# Word not exist in vocab: 4
# Word not exist in vocab: كهف،سبا،
# Word not exist in vocab: انعام،الكهف
# Word not exist in vocab: تتلال
# Word not exist in vocab: خالق،
# Word not exist in vocab: فاطربد
# Word not exist in vocab: هيالكهف،
# Word not exist in vocab: نهل،
# Word not exist in vocab: فتشرق
# Word not exist in vocab: نساب
# Word not exist in vocab: كاصابع
# Word not exist in vocab: بتق
# Word not exist in vocab: صابرة،
# Word not exist in vocab: انجيل،
# Word not exist in vocab: صطف
# Word not exist in vocab: ثب
# Word not exist in vocab: خترع
# Word not exist in vocab: دة،
# Word not exist in vocab: ختراع
# Word not exist in vocab: حترم
# Word not exist in vocab: دتين
# Word not exist in vocab: هاجرالعذراء
# Word not exist in vocab: اجبة
# Word not exist in vocab: موذج
# Word not exist in vocab: زما
# Word not exist in vocab: نساءهي
# Word not exist in vocab: احديث
# Word not exist in vocab: حتفل
# Word not exist in vocab: ثقاف
# Word not exist in vocab: ارتق
# Word not exist in vocab: فشرف
# Word not exist in vocab: بمثاب
# Word not exist in vocab: انير
# Word not exist in vocab: سلمت،
# Word not exist in vocab: حتفي
# Word not exist in vocab: لشا
# Word not exist in vocab: حتوئ
# Word not exist in vocab: ستثنائ
# Word not exist in vocab: ستثني
# Word not exist in vocab: انتبا
# Word not exist in vocab: فترض
# Word not exist in vocab: لتو
# Word not exist in vocab: بكلم
# Word not exist in vocab: احي
# Word not exist in vocab: خلاقه،
# Word not exist in vocab: احديث،
# Word not exist in vocab: بدماث
# Word not exist in vocab: اسق
# Word not exist in vocab: تعطر
# Word not exist in vocab: بحليم
# Word not exist in vocab: ختير
# Word not exist in vocab: لترضاع
# Word not exist in vocab: برضاع
# Word not exist in vocab: ونس،
# Word not exist in vocab: برحم
# Word not exist in vocab: سرائيل
# Word not exist in vocab: متاكدا،
# Word not exist in vocab: يقط
# Word not exist in vocab: 41،
# Word not exist in vocab: فيء،
# Word not exist in vocab: عدء
# Word not exist in vocab: 41
# Word not exist in vocab: ركيز
# Word not exist in vocab: ؤسس
# Word not exist in vocab: ضعت،
# Word not exist in vocab: لترسي
# Word not exist in vocab: بانصاف
# Word not exist in vocab: مشركين،
# Word not exist in vocab: رتبط
# Word not exist in vocab: رتباط
# Word not exist in vocab: ثيق
# Word not exist in vocab: اضح
# Word not exist in vocab: اريخي،
# Word not exist in vocab: خصيص
# Word not exist in vocab: رسء
# Word not exist in vocab: رسي
# Word not exist in vocab: بتواز
# Word not exist in vocab: 16
# Word not exist in vocab: 196
# Word not exist in vocab: كافرو
# Word not exist in vocab: جاثي
# Word not exist in vocab: نشقق
# Word not exist in vocab: مطفف
# Word not exist in vocab: عتبرهي
# Word not exist in vocab: اثنت
# Word not exist in vocab: تتك

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.30983999, -0.13467   , -0.73664999, ..., -0.32602999,
#         -0.21698999, -0.29073   ],
#        [ 0.21615   ,  0.21889   , -0.049481  , ..., -0.13906001,
#          0.12826   ,  0.36548001],
#        ...,
#        [-0.37913001,  0.90614003, -0.30304   , ..., -0.21646   ,
#          0.085595  ,  0.34847   ],
#        [ 0.024534  ,  0.40884   , -0.45969999, ..., -0.34301001,
#          0.17645   , -0.40713999],
#        [-0.27902001, -0.022783  , -0.23921999, ..., -0.31531999,
#          0.037558  ,  0.30046999]])

# %%
from sklearn.model_selection import train_test_split
# concatenate question number with 
X_train, X_test, y_train, y_test = train_test_split(sequences, scores, test_size=0.2)

# %%
# train model
from keras.regularizers import l1
from keras.models import Sequential
from keras.layers import Dense, Embedding,Input,Dropout,Flatten
from keras.layers import LSTM
from keras.models import Model

print('Build model...')

inp = Input(shape=(max_sequence_length,))
model = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=max_sequence_length,
                            trainable=False)(inp)
model = LSTM(units=64, return_sequences=True, return_state=False ,  activation= tf.keras.activations.relu)(model)
model = Dropout(0.2)(model)
model = Flatten()(model)
model = Dense(32, activation=tf.keras.activations.relu)(model)
model = Dropout(0.2)(model)
model = Dense(3, activation=tf.keras.activations.softmax)(model)
model = Model(inputs=inp, outputs=model)
# Out:
# Build model...
# WARNING:tensorflow:From c:\Users\chaimae\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
import tensorflow_addons as tfa
#https://neptune.ai/blog/tensorboard-tutorial
tensorboard_callback = TensorBoard(log_dir="./logs")
#Early stopping
es_callback = tf.keras.callbacks.EarlyStopping(monitor='loss',patience=3,verbose=1,mode='min')
keras_callbacks = [
  tensorboard_callback ,es_callback
]
#metrics=['accuracy',tf.keras.metrics.Precision(), tf.keras.metrics.Recall(),f1_m,tfa.metrics.CohenKappa(num_classes=3)]
# try using different optimizers and different optimizer configs
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),
              metrics=['accuracy',tf.keras.metrics.Precision(), tf.keras.metrics.Recall(),f1_m,tfa.metrics.CohenKappa(num_classes=3)])

model.summary()
# Out:
# c:\Users\chaimae\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\chaimae\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32)]              0
#
#  embedding (Embedding)       (None, 32, 300)           323700
#
#  lstm (LSTM)                 (None, 32, 64)            93440
#
#  dropout (Dropout)           (None, 32, 64)            0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 32)                65568
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 482807 (1.84 MB)
# Trainable params: 159107 (621.51 KB)
# Non-trainable params: 323700 (1.23 MB)
# _________________________________________________________________

# %%
from time import time

# %%
# %reload_ext tensorboard
log_folder = 'logs'

print('Train...')
time_start = time()
hisotry = model.fit(X_train, y_train,batch_size=256,epochs=150,callbacks=keras_callbacks,validation_data=(X_test, y_test)) 
time_start = time() - time_start

print("Took : "+str(np.round(time_start, 2))+" (s)") 

#model.save('asag_lstm_model.h5')
# Out:
# Train...
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\chaimae\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\chaimae\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 11s 928ms/step - loss: 1.0788 - accuracy: 0.3764 - precision: 1.0000 - recall: 0.0057 - f1_m: 0.0142 - cohen_kappa: 0.0503 - val_loss: 1.0256 - val_accuracy: 0.4655 - val_precision: 0.7143 - val_recall: 0.0862 - val_f1_m: 0.1538 - val_cohen_kappa: 0.0000e+00
# Epoch 2/150
# 3/3 [==============================] - 0s 145ms/step - loss: 0.9780 - accuracy: 0.5259 - precision: 0.7326 - recall: 0.1810 - f1_m: 0.2948 - cohen_kappa: 0.0079 - val_loss: 0.9852 - val_accuracy: 0.4655 - val_precision: 0.6203 - val_recall: 0.2816 - val_f1_m: 0.3874 - val_cohen_kappa: 0.0000e+00
# Epoch 3/150
# 3/3 [==============================] - 0s 141ms/step - loss: 0.9336 - accuracy: 0.5216 - precision: 0.6842 - recall: 0.3736 - f1_m: 0.4862 - cohen_kappa: -0.0021 - val_loss: 0.9780 - val_accuracy: 0.4655 - val_precision: 0.5577 - val_recall: 0.3333 - val_f1_m: 0.4173 - val_cohen_kappa: 0.0000e+00
# Epoch 4/150
# 3/3 [==============================] - 0s 159ms/step - loss: 0.9100 - accuracy: 0.5374 - precision: 0.6819 - recall: 0.4066 - f1_m: 0.5097 - cohen_kappa: 0.0390 - val_loss: 0.9267 - val_accuracy: 0.5402 - val_precision: 0.5699 - val_recall: 0.3046 - val_f1_m: 0.3970 - val_cohen_kappa: 0.1457
# Epoch 5/150
# 3/3 [==============================] - 0s 180ms/step - loss: 0.8856 - accuracy: 0.6049 - precision: 0.6841 - recall: 0.3764 - f1_m: 0.4826 - cohen_kappa: 0.2184 - val_loss: 0.8983 - val_accuracy: 0.5690 - val_precision: 0.6104 - val_recall: 0.2701 - val_f1_m: 0.3745 - val_cohen_kappa: 0.2116
# Epoch 6/150
# 3/3 [==============================] - 0s 177ms/step - loss: 0.8669 - accuracy: 0.6221 - precision: 0.7112 - recall: 0.3290 - f1_m: 0.4510 - cohen_kappa: 0.2796 - val_loss: 0.8857 - val_accuracy: 0.5402 - val_precision: 0.6104 - val_recall: 0.2701 - val_f1_m: 0.3745 - val_cohen_kappa: 0.1640
# Epoch 7/150
# 3/3 [==============================] - 0s 157ms/step - loss: 0.8680 - accuracy: 0.6164 - precision: 0.7179 - recall: 0.3290 - f1_m: 0.4481 - cohen_kappa: 0.2807 - val_loss: 0.8794 - val_accuracy: 0.5747 - val_precision: 0.5652 - val_recall: 0.2989 - val_f1_m: 0.3910 - val_cohen_kappa: 0.2231
# Epoch 8/150
# 3/3 [==============================] - 0s 161ms/step - loss: 0.8289 - accuracy: 0.6379 - precision: 0.6944 - recall: 0.3951 - f1_m: 0.5022 - cohen_kappa: 0.3079 - val_loss: 0.8808 - val_accuracy: 0.5977 - val_precision: 0.5670 - val_recall: 0.3161 - val_f1_m: 0.4059 - val_cohen_kappa: 0.2645
# Epoch 9/150
# 3/3 [==============================] - 0s 168ms/step - loss: 0.8205 - accuracy: 0.6365 - precision: 0.7044 - recall: 0.4382 - f1_m: 0.5402 - cohen_kappa: 0.3064 - val_loss: 0.8578 - val_accuracy: 0.5690 - val_precision: 0.5895 - val_recall: 0.3218 - val_f1_m: 0.4164 - val_cohen_kappa: 0.2163
# Epoch 10/150
# 3/3 [==============================] - 1s 268ms/step - loss: 0.8006 - accuracy: 0.6624 - precision: 0.7289 - recall: 0.4828 - f1_m: 0.5861 - cohen_kappa: 0.3737 - val_loss: 0.8285 - val_accuracy: 0.5862 - val_precision: 0.7143 - val_recall: 0.4598 - val_f1_m: 0.5594 - val_cohen_kappa: 0.2542
# Epoch 11/150
# 3/3 [==============================] - 0s 155ms/step - loss: 0.7769 - accuracy: 0.6681 - precision: 0.7450 - recall: 0.5330 - f1_m: 0.6215 - cohen_kappa: 0.3935 - val_loss: 0.8211 - val_accuracy: 0.6092 - val_precision: 0.6667 - val_recall: 0.5057 - val_f1_m: 0.5752 - val_cohen_kappa: 0.2939
# Epoch 12/150
# 3/3 [==============================] - 0s 137ms/step - loss: 0.7431 - accuracy: 0.6710 - precision: 0.7309 - recall: 0.5776 - f1_m: 0.6471 - cohen_kappa: 0.3956 - val_loss: 0.8176 - val_accuracy: 0.6264 - val_precision: 0.6714 - val_recall: 0.5402 - val_f1_m: 0.5987 - val_cohen_kappa: 0.3245
# Epoch 13/150
# 3/3 [==============================] - 0s 138ms/step - loss: 0.7157 - accuracy: 0.7011 - precision: 0.7573 - recall: 0.5963 - f1_m: 0.6681 - cohen_kappa: 0.4510 - val_loss: 0.7801 - val_accuracy: 0.6207 - val_precision: 0.6690 - val_recall: 0.5575 - val_f1_m: 0.6082 - val_cohen_kappa: 0.3169
# Epoch 14/150
# 3/3 [==============================] - 0s 129ms/step - loss: 0.6771 - accuracy: 0.7241 - precision: 0.7707 - recall: 0.6422 - f1_m: 0.6999 - cohen_kappa: 0.5010 - val_loss: 0.7826 - val_accuracy: 0.6552 - val_precision: 0.6986 - val_recall: 0.5862 - val_f1_m: 0.6375 - val_cohen_kappa: 0.3769
# Epoch 15/150
# 3/3 [==============================] - 0s 127ms/step - loss: 0.6380 - accuracy: 0.7270 - precision: 0.7847 - recall: 0.6652 - f1_m: 0.7187 - cohen_kappa: 0.4989 - val_loss: 0.7187 - val_accuracy: 0.6839 - val_precision: 0.7086 - val_recall: 0.6149 - val_f1_m: 0.6585 - val_cohen_kappa: 0.4296
# Epoch 16/150
# 3/3 [==============================] - 0s 118ms/step - loss: 0.6034 - accuracy: 0.7601 - precision: 0.8040 - recall: 0.6954 - f1_m: 0.7466 - cohen_kappa: 0.5658 - val_loss: 0.7650 - val_accuracy: 0.7011 - val_precision: 0.7403 - val_recall: 0.6552 - val_f1_m: 0.6951 - val_cohen_kappa: 0.4582
# Epoch 17/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.5900 - accuracy: 0.7557 - precision: 0.7980 - recall: 0.6983 - f1_m: 0.7442 - cohen_kappa: 0.5517 - val_loss: 0.6684 - val_accuracy: 0.7299 - val_precision: 0.7516 - val_recall: 0.6609 - val_f1_m: 0.7034 - val_cohen_kappa: 0.5117
# Epoch 18/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.5455 - accuracy: 0.7687 - precision: 0.8151 - recall: 0.7284 - f1_m: 0.7699 - cohen_kappa: 0.5822 - val_loss: 0.6950 - val_accuracy: 0.7414 - val_precision: 0.7595 - val_recall: 0.6897 - val_f1_m: 0.7229 - val_cohen_kappa: 0.5302
# Epoch 19/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.5233 - accuracy: 0.7902 - precision: 0.8403 - recall: 0.7486 - f1_m: 0.7951 - cohen_kappa: 0.6129 - val_loss: 0.6291 - val_accuracy: 0.7874 - val_precision: 0.7974 - val_recall: 0.7011 - val_f1_m: 0.7462 - val_cohen_kappa: 0.6166
# Epoch 20/150
# 3/3 [==============================] - 0s 129ms/step - loss: 0.5080 - accuracy: 0.7974 - precision: 0.8395 - recall: 0.7514 - f1_m: 0.7931 - cohen_kappa: 0.6332 - val_loss: 0.7587 - val_accuracy: 0.7471 - val_precision: 0.7744 - val_recall: 0.7299 - val_f1_m: 0.7515 - val_cohen_kappa: 0.5406
# Epoch 21/150
# 3/3 [==============================] - 0s 129ms/step - loss: 0.4675 - accuracy: 0.8190 - precision: 0.8502 - recall: 0.7830 - f1_m: 0.8178 - cohen_kappa: 0.6654 - val_loss: 0.5959 - val_accuracy: 0.7701 - val_precision: 0.8089 - val_recall: 0.7299 - val_f1_m: 0.7674 - val_cohen_kappa: 0.5860
# Epoch 22/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.4696 - accuracy: 0.8060 - precision: 0.8498 - recall: 0.7802 - f1_m: 0.8128 - cohen_kappa: 0.6502 - val_loss: 0.6754 - val_accuracy: 0.7759 - val_precision: 0.7904 - val_recall: 0.7586 - val_f1_m: 0.7742 - val_cohen_kappa: 0.5930
# Epoch 23/150
# 3/3 [==============================] - 0s 129ms/step - loss: 0.4348 - accuracy: 0.8319 - precision: 0.8666 - recall: 0.7931 - f1_m: 0.8296 - cohen_kappa: 0.6897 - val_loss: 0.7845 - val_accuracy: 0.7701 - val_precision: 0.7784 - val_recall: 0.7471 - val_f1_m: 0.7625 - val_cohen_kappa: 0.5824
# Epoch 24/150
# 3/3 [==============================] - 0s 122ms/step - loss: 0.4195 - accuracy: 0.8333 - precision: 0.8694 - recall: 0.8032 - f1_m: 0.8321 - cohen_kappa: 0.6971 - val_loss: 0.6103 - val_accuracy: 0.7471 - val_precision: 0.8153 - val_recall: 0.7356 - val_f1_m: 0.7734 - val_cohen_kappa: 0.5461
# Epoch 25/150
# 3/3 [==============================] - 0s 131ms/step - loss: 0.3858 - accuracy: 0.8448 - precision: 0.8746 - recall: 0.8118 - f1_m: 0.8411 - cohen_kappa: 0.7189 - val_loss: 0.8138 - val_accuracy: 0.7586 - val_precision: 0.7738 - val_recall: 0.7471 - val_f1_m: 0.7602 - val_cohen_kappa: 0.5615
# Epoch 26/150
# 3/3 [==============================] - 0s 131ms/step - loss: 0.3845 - accuracy: 0.8491 - precision: 0.8810 - recall: 0.8190 - f1_m: 0.8479 - cohen_kappa: 0.7227 - val_loss: 0.6703 - val_accuracy: 0.7644 - val_precision: 0.7901 - val_recall: 0.7356 - val_f1_m: 0.7619 - val_cohen_kappa: 0.5753
# Epoch 27/150
# 3/3 [==============================] - 0s 132ms/step - loss: 0.3777 - accuracy: 0.8463 - precision: 0.8715 - recall: 0.8089 - f1_m: 0.8374 - cohen_kappa: 0.7219 - val_loss: 0.7065 - val_accuracy: 0.7759 - val_precision: 0.7914 - val_recall: 0.7414 - val_f1_m: 0.7656 - val_cohen_kappa: 0.5952
# Epoch 28/150
# 3/3 [==============================] - 0s 125ms/step - loss: 0.3515 - accuracy: 0.8649 - precision: 0.8972 - recall: 0.8276 - f1_m: 0.8603 - cohen_kappa: 0.7533 - val_loss: 0.8597 - val_accuracy: 0.7759 - val_precision: 0.7927 - val_recall: 0.7471 - val_f1_m: 0.7692 - val_cohen_kappa: 0.5931
# Epoch 29/150
# 3/3 [==============================] - 0s 139ms/step - loss: 0.3452 - accuracy: 0.8649 - precision: 0.8926 - recall: 0.8362 - f1_m: 0.8613 - cohen_kappa: 0.7553 - val_loss: 0.7036 - val_accuracy: 0.7701 - val_precision: 0.7892 - val_recall: 0.7529 - val_f1_m: 0.7706 - val_cohen_kappa: 0.5877
# Epoch 30/150
# 3/3 [==============================] - 0s 193ms/step - loss: 0.3128 - accuracy: 0.8750 - precision: 0.9073 - recall: 0.8434 - f1_m: 0.8750 - cohen_kappa: 0.7749 - val_loss: 0.8684 - val_accuracy: 0.7816 - val_precision: 0.8000 - val_recall: 0.7586 - val_f1_m: 0.7788 - val_cohen_kappa: 0.6054
# Epoch 31/150
# 3/3 [==============================] - 0s 156ms/step - loss: 0.3121 - accuracy: 0.8736 - precision: 0.8916 - recall: 0.8506 - f1_m: 0.8677 - cohen_kappa: 0.7707 - val_loss: 0.8266 - val_accuracy: 0.7701 - val_precision: 0.7939 - val_recall: 0.7529 - val_f1_m: 0.7729 - val_cohen_kappa: 0.5863
# Epoch 32/150
# 3/3 [==============================] - 0s 141ms/step - loss: 0.2988 - accuracy: 0.8793 - precision: 0.9132 - recall: 0.8621 - f1_m: 0.8876 - cohen_kappa: 0.7824 - val_loss: 0.7497 - val_accuracy: 0.7644 - val_precision: 0.7927 - val_recall: 0.7471 - val_f1_m: 0.7692 - val_cohen_kappa: 0.5780
# Epoch 33/150
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2769 - accuracy: 0.8937 - precision: 0.9158 - recall: 0.8592 - f1_m: 0.8871 - cohen_kappa: 0.8087 - val_loss: 0.9200 - val_accuracy: 0.7759 - val_precision: 0.8000 - val_recall: 0.7586 - val_f1_m: 0.7788 - val_cohen_kappa: 0.5994
# Epoch 34/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.2734 - accuracy: 0.8922 - precision: 0.9115 - recall: 0.8736 - f1_m: 0.8931 - cohen_kappa: 0.8063 - val_loss: 1.0978 - val_accuracy: 0.7701 - val_precision: 0.8098 - val_recall: 0.7586 - val_f1_m: 0.7834 - val_cohen_kappa: 0.5892
# Epoch 35/150
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2643 - accuracy: 0.8980 - precision: 0.9094 - recall: 0.8793 - f1_m: 0.8931 - cohen_kappa: 0.8176 - val_loss: 1.1394 - val_accuracy: 0.7701 - val_precision: 0.7917 - val_recall: 0.7644 - val_f1_m: 0.7778 - val_cohen_kappa: 0.5923
# Epoch 36/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.2598 - accuracy: 0.8951 - precision: 0.9201 - recall: 0.8764 - f1_m: 0.8984 - cohen_kappa: 0.8135 - val_loss: 2.0212 - val_accuracy: 0.7701 - val_precision: 0.7917 - val_recall: 0.7644 - val_f1_m: 0.7778 - val_cohen_kappa: 0.5896
# Epoch 37/150
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2519 - accuracy: 0.9124 - precision: 0.9362 - recall: 0.8851 - f1_m: 0.9096 - cohen_kappa: 0.8446 - val_loss: 0.7528 - val_accuracy: 0.7759 - val_precision: 0.7917 - val_recall: 0.7644 - val_f1_m: 0.7778 - val_cohen_kappa: 0.6016
# Epoch 38/150
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2683 - accuracy: 0.8951 - precision: 0.9172 - recall: 0.8750 - f1_m: 0.8943 - cohen_kappa: 0.8120 - val_loss: 0.8877 - val_accuracy: 0.7759 - val_precision: 0.7791 - val_recall: 0.7701 - val_f1_m: 0.7746 - val_cohen_kappa: 0.5989
# Epoch 39/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2313 - accuracy: 0.9138 - precision: 0.9293 - recall: 0.8879 - f1_m: 0.9076 - cohen_kappa: 0.8456 - val_loss: 0.8533 - val_accuracy: 0.7816 - val_precision: 0.7941 - val_recall: 0.7759 - val_f1_m: 0.7849 - val_cohen_kappa: 0.6105
# Epoch 40/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2300 - accuracy: 0.9023 - precision: 0.9254 - recall: 0.8908 - f1_m: 0.9072 - cohen_kappa: 0.8257 - val_loss: 1.0956 - val_accuracy: 0.7701 - val_precision: 0.7882 - val_recall: 0.7701 - val_f1_m: 0.7791 - val_cohen_kappa: 0.5888
# Epoch 41/150
# 3/3 [==============================] - 0s 115ms/step - loss: 0.2309 - accuracy: 0.9138 - precision: 0.9241 - recall: 0.8922 - f1_m: 0.9082 - cohen_kappa: 0.8471 - val_loss: 1.1564 - val_accuracy: 0.7759 - val_precision: 0.7882 - val_recall: 0.7701 - val_f1_m: 0.7791 - val_cohen_kappa: 0.5993
# Epoch 42/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.2192 - accuracy: 0.9167 - precision: 0.9373 - recall: 0.9023 - f1_m: 0.9176 - cohen_kappa: 0.8532 - val_loss: 1.0202 - val_accuracy: 0.7816 - val_precision: 0.7917 - val_recall: 0.7644 - val_f1_m: 0.7778 - val_cohen_kappa: 0.6116
# Epoch 43/150
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2176 - accuracy: 0.9124 - precision: 0.9294 - recall: 0.8894 - f1_m: 0.9105 - cohen_kappa: 0.8453 - val_loss: 1.0345 - val_accuracy: 0.7874 - val_precision: 0.7907 - val_recall: 0.7816 - val_f1_m: 0.7861 - val_cohen_kappa: 0.6198
# Epoch 44/150
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2125 - accuracy: 0.9224 - precision: 0.9376 - recall: 0.9066 - f1_m: 0.9191 - cohen_kappa: 0.8624 - val_loss: 0.9445 - val_accuracy: 0.7816 - val_precision: 0.7803 - val_recall: 0.7759 - val_f1_m: 0.7781 - val_cohen_kappa: 0.6100
# Epoch 45/150
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2039 - accuracy: 0.9267 - precision: 0.9359 - recall: 0.9023 - f1_m: 0.9179 - cohen_kappa: 0.8698 - val_loss: 0.9070 - val_accuracy: 0.7989 - val_precision: 0.7977 - val_recall: 0.7931 - val_f1_m: 0.7954 - val_cohen_kappa: 0.6413
# Epoch 46/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.1873 - accuracy: 0.9310 - precision: 0.9518 - recall: 0.9080 - f1_m: 0.9280 - cohen_kappa: 0.8783 - val_loss: 0.9843 - val_accuracy: 0.7874 - val_precision: 0.7874 - val_recall: 0.7874 - val_f1_m: 0.7874 - val_cohen_kappa: 0.6204
# Epoch 47/150
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1996 - accuracy: 0.9195 - precision: 0.9387 - recall: 0.9023 - f1_m: 0.9198 - cohen_kappa: 0.8586 - val_loss: 1.0525 - val_accuracy: 0.7931 - val_precision: 0.7953 - val_recall: 0.7816 - val_f1_m: 0.7884 - val_cohen_kappa: 0.6312
# Epoch 48/150
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1741 - accuracy: 0.9325 - precision: 0.9525 - recall: 0.9210 - f1_m: 0.9342 - cohen_kappa: 0.8810 - val_loss: 1.2459 - val_accuracy: 0.7759 - val_precision: 0.7759 - val_recall: 0.7759 - val_f1_m: 0.7759 - val_cohen_kappa: 0.5994
# Epoch 49/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.1732 - accuracy: 0.9310 - precision: 0.9436 - recall: 0.9138 - f1_m: 0.9282 - cohen_kappa: 0.8782 - val_loss: 1.2049 - val_accuracy: 0.7874 - val_precision: 0.7861 - val_recall: 0.7816 - val_f1_m: 0.7839 - val_cohen_kappa: 0.6206
# Epoch 50/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.1756 - accuracy: 0.9325 - precision: 0.9480 - recall: 0.9167 - f1_m: 0.9327 - cohen_kappa: 0.8809 - val_loss: 1.1521 - val_accuracy: 0.7816 - val_precision: 0.7803 - val_recall: 0.7759 - val_f1_m: 0.7781 - val_cohen_kappa: 0.6118
# Epoch 51/150
# 3/3 [==============================] - 0s 118ms/step - loss: 0.1601 - accuracy: 0.9368 - precision: 0.9501 - recall: 0.9296 - f1_m: 0.9395 - cohen_kappa: 0.8888 - val_loss: 1.1703 - val_accuracy: 0.7644 - val_precision: 0.7630 - val_recall: 0.7586 - val_f1_m: 0.7608 - val_cohen_kappa: 0.5803
# Epoch 52/150
# 3/3 [==============================] - 0s 110ms/step - loss: 0.1572 - accuracy: 0.9411 - precision: 0.9472 - recall: 0.9282 - f1_m: 0.9373 - cohen_kappa: 0.8958 - val_loss: 1.3336 - val_accuracy: 0.7586 - val_precision: 0.7586 - val_recall: 0.7586 - val_f1_m: 0.7586 - val_cohen_kappa: 0.5709
# Epoch 53/150
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1800 - accuracy: 0.9296 - precision: 0.9439 - recall: 0.9181 - f1_m: 0.9321 - cohen_kappa: 0.8758 - val_loss: 1.3061 - val_accuracy: 0.7701 - val_precision: 0.7733 - val_recall: 0.7644 - val_f1_m: 0.7688 - val_cohen_kappa: 0.5912
# Epoch 54/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.1528 - accuracy: 0.9382 - precision: 0.9538 - recall: 0.9195 - f1_m: 0.9361 - cohen_kappa: 0.8918 - val_loss: 1.5335 - val_accuracy: 0.7759 - val_precision: 0.7746 - val_recall: 0.7701 - val_f1_m: 0.7723 - val_cohen_kappa: 0.6014
# Epoch 55/150
# 3/3 [==============================] - 0s 108ms/step - loss: 0.1518 - accuracy: 0.9382 - precision: 0.9553 - recall: 0.9210 - f1_m: 0.9392 - cohen_kappa: 0.8917 - val_loss: 1.0513 - val_accuracy: 0.7759 - val_precision: 0.7803 - val_recall: 0.7759 - val_f1_m: 0.7781 - val_cohen_kappa: 0.6035
# Epoch 56/150
# 3/3 [==============================] - 0s 115ms/step - loss: 0.1612 - accuracy: 0.9325 - precision: 0.9440 - recall: 0.9210 - f1_m: 0.9323 - cohen_kappa: 0.8817 - val_loss: 1.5256 - val_accuracy: 0.7874 - val_precision: 0.7874 - val_recall: 0.7874 - val_f1_m: 0.7874 - val_cohen_kappa: 0.6210
# Epoch 57/150
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1896 - accuracy: 0.9282 - precision: 0.9350 - recall: 0.9095 - f1_m: 0.9206 - cohen_kappa: 0.8739 - val_loss: 0.9742 - val_accuracy: 0.7529 - val_precision: 0.7558 - val_recall: 0.7471 - val_f1_m: 0.7514 - val_cohen_kappa: 0.5633
# Epoch 58/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.1716 - accuracy: 0.9210 - precision: 0.9309 - recall: 0.9095 - f1_m: 0.9222 - cohen_kappa: 0.8616 - val_loss: 1.4482 - val_accuracy: 0.7701 - val_precision: 0.7778 - val_recall: 0.7644 - val_f1_m: 0.7710 - val_cohen_kappa: 0.5913
# Epoch 58: early stopping
# Took : 32.25 (s)

# %%
scores_trainig = model.evaluate(X_train, y_train, verbose=1)
print("Training Loss: %f%%" % (scores_trainig[0]))
print("Training Accuracy: %.2f%%" % (scores_trainig[1]*100))
print("Training Precision: %.2f%%" % (scores_trainig[2]*100))
print("Training Recall: %.2f%%" % (scores_trainig[3]*100))
print("Training F1 Score: %.2f%%" % (scores_trainig[4]*100))
print("Training Cohen Kappa: %.2f%%" % (scores_trainig[5]*100))
# Out:
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1356 - accuracy: 0.9397 - precision: 0.9460 - recall: 0.9310 - f1_m: 0.9379 - cohen_kappa: 0.8930
# Training Loss: 0.135574%
# Training Accuracy: 93.97%
# Training Precision: 94.60%
# Training Recall: 93.10%
# Training F1 Score: 93.79%
# Training Cohen Kappa: 89.30%

# %%
scores_test = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss: %f%%" % (scores_test[0]))
print("Test Accuracy: %.2f%%" % (scores_test[1]*100))
print("Test Precision: %.2f%%" % (scores_test[2]*100))
print("Test Recall: %.2f%%" % (scores_test[3]*100))
print("Test F1 Score: %.2f%%" % (scores_test[4]*100))
print("Test Cohen Kappa: %.2f%%" % (scores_test[5]*100))
# Out:
# 6/6 [==============================] - 0s 10ms/step - loss: 1.4482 - accuracy: 0.7701 - precision: 0.7778 - recall: 0.7644 - f1_m: 0.7724 - cohen_kappa: 0.5913
# Test Loss: 1.448241%
# Test Accuracy: 77.01%
# Test Precision: 77.78%
# Test Recall: 76.44%
# Test F1 Score: 77.24%
# Test Cohen Kappa: 59.13%

# %%
'''
# %reload_ext tensorboard
log_folder = 'logs'
# %tensorboard --logdir={log_folder}
'''
import matplotlib.pyplot as plt
print(hisotry.history.keys())

# summarize history for accuracy
plt.plot(hisotry.history['accuracy'])
plt.plot(hisotry.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hisotry.history['loss'])
plt.plot(hisotry.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for kappa
plt.plot(hisotry.history['cohen_kappa'])
plt.plot(hisotry.history['val_cohen_kappa'])
plt.title('model loss')
plt.ylabel('cohen_kappa')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for kappa
plt.plot(hisotry.history['f1_m'])
plt.plot(hisotry.history['val_f1_m'])
plt.title('model F1')
plt.ylabel('cohen_kappa')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'f1_m', 'cohen_kappa', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_f1_m', 'val_cohen_kappa'])
